# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = []
y = []
with open('prod.dat') as f:
    data = f.readlines()

for el in data:
    el = el.strip()
    x.append(int(el.split()[0])
    y.append(el.split()[1])
# Out:
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# 0 -18421.2263
#
# ...

# %%
print(x,y)
